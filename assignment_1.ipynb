# %%
#Read the file
with open('example.txt','r') as f:
 data=f.read()
#Repalce with the target string
data=data.replace('placement','screening')
#Wrtie the data into the file
with open('example.txt','w') as f:
  f.write(data)
