# %% [raw]
# 1.Why ae functions advantageous to have in your program?

# %% [raw]
# in order to provide some features or functionaliites or services we write  statments .  if same functionality is required  in varioius parts of  the program  we no need to write the same statments again, instead we write these statements  in the body of the function  whenever we need the functionality we can call the function

# %% [raw]
# 2. When does the code in a function run: when it's specified or when it's called?

# %% [raw]
# def key word is used to define a function in Python . funcction defination contains the body of the function which carries out some well defined task. when ever we need the task to be performed we need to invoke the function this process is known as function calling. when a function is called then it comes into exuction and the statmetns in the function body are executed

# %% [raw]
# 3. What statement creates a function?

# %% [raw]
# A function can be created using the follwing syntax
#
# def <function_name>(parameterlist):
#       body

# %% [raw]
# 4. What is the difference between a function and a function call?

# %% [raw]
# A function is a block of statments that performs a single indentifiable job.
# A function definition contains one or more statements
# when ever we want to get the service of a function then we have to call the parameters using the function name follwoed a parenthesis with optional parameters
#
# example:
# #function definition
# def sum(x,y):
#   z=x+y
#   return z
# #function calling
# result=sum(3,5)
# print('sum=',result)

# %% [raw]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %% [raw]
# variables defined out side all the functions or variables defined with in a function using global keyword are the global variables.
# global variables can be accessed form any where in the same python program or from another program
#
# vairbales used as parameters in the function header and the vaiabels defined in the function body are in the local scope.

# %% [raw]
# 6. What happens to variables in a local scope when the function call returns?

# %% [raw]
# when return statement encountrs then control will be transferred back to the calling function. then all local variables of the function are vanished .

# %% [raw]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [raw]
# return statement returns the control along with a value (optional) to the calling function. return statement may have a value or an expression . if return statement has an expression then first the expresssion is evaluated and the value is returned

# %% [raw]
# 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [raw]
# return statement is an optional statemnt in the function body . if a function does not contain any return value
# then by default the function returns None

# %% [raw]
# 9. How do you make a function variable refer to the global variable?

# %% [raw]
# using global keyword

# %% [raw]
# 10. What is the data type of None?

# %% [raw]
# None is an empty object . An object that does not have any valid data

# %% [raw]
# 11. What does the sentence import areallyourpetsnamederic do?

# %% [raw]
# imports all the variables , functions, classes in the given module

# %% [raw]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [raw]
# import spam
# spam.bacon()

# %% [raw]
# 13. What can you do to save a programme from crashing if it encounters an error?

# %% [raw]
# handle the exception using try ..except ...finally

# %% [raw]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [raw]
# the statements that may raise the exception those statements we must take unde try clause . if any exceptio is raised in the try
# clause then approriate exception type object is created by the python run time environment , to handle the exception we need
# to define the approriate matching except clause
#
# example:
#
# try:
#   pritn(10/0)
# except ZeroDivisionError as e:
#   print(e)
