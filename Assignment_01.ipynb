# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [raw]
# Values are:
# ------------
# 'hello'
# -87.8
# 6
#
# expressions are:
# -----------------
# *
# -
# /
# +

# %% [raw]
# 2. What is the difference between string and variable?

# %% [raw]
# A varible in python is an object reference that refers to an object .
# varibles are not bound with type but values are .
# python is a dynamically typed langauge the type of the variable is decided based on the value assigned to the variable
#
# string is a collection of unicode characters enclosed with in single quotes  or double quotes  or tripe single quotea or triple double quotes.
# string is one of the basic data type in python . it is an immutable object . once the value is set it can not be modified

# %% [raw]
# 3. Describe three different data types.

# %% [raw]
# basic data types : int , float ,str, bool , char
# python collections: list ,tuple, set, dict
# other data types : range, None

# %% [raw]
# 4. What is an expression made up of? What do all expressions do?

# %% [raw]
# An expression is any valid python statement that has some value or that evalues to a value.
# expressions evaluates to a value.
# Example :
# arithmetic expressions : 2 + 3
#                          2 +3 *5
# boolean expressions : 10>20
#
# x=10 => the value of this expression is the vlaue assigned to the left side variable
# print('Hello!') => the vlaue of the expresion is the execution of the body of the funciton print

# %% [raw]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [raw]
# detailed explanation is given in the ansswer to the question 4

# %% [raw]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [raw]
# bacon contain 22

# %% [raw]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %% [raw]
# both the statements the result is same .
# second statement is string repetiton operation which internally applies concatenation operation

# %% [raw]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [raw]
# In python identifers are sequnce of charcters . but idententifer follows some rules
# identifier can contain letters , digits and an underscroe symbol but it should not begin with a digit

# %% [raw]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [raw]
# int()
# float()
# str()

# %% [raw]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.

# %%
cocatenation operation can be performed on strings only .
